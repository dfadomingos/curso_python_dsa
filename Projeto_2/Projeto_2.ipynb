# %% [markdown]
# ## Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# #### Carregando os Dados

# %%
df = pd.read_csv('dados/dataset.csv')

# %%
df.shape
# Out:
# (9700, 11)

# %%
#5 primeiras linhas
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
#5 últimas linhas
df.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# #### Análise Exploratória

# %%
#colunas do conjuntos de dados
df.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
#verificando os tipos das colunas
df.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
#resumo estatistico da coluna 'valor venda'
df['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
#verificando se há registros duplicados
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
#verificando se há valores nulos
df.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %% [markdown]
# ### Pergunta de Negócio 1:
#
# #### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
#filtrando as categorias
df_p1 = df[df['Categoria'] == 'Office Supplies']

# %%
#agrupando por cidade e realizando a soma do total de venda
df_p1_total_venda = df_p1.groupby('Cidade')['Valor_Venda'].sum()

# %%
cidade_maior_venda = df_p1_total_venda.idxmax()
maior_valor = df_p1_total_venda.max()

print(f'Cidade com o maior valor de venda foi {cidade_maior_venda} com valor de {maior_valor}')
# Out:
# Cidade com o maior valor de venda foi New York City com valor de 68362.814

# %%
#conferindo resultado
df_p1_total_venda.sort_values(ascending = False)
# Out:
# Cidade
# New York City    68362.814
# Los Angeles      47098.100
# San Francisco    41771.198
# Seattle          34856.878
# Philadelphia     29313.687
#                    ...
# Ormond Beach         2.808
# Pensacola            2.214
# Jupiter              2.064
# Elyria               1.824
# Abilene              1.392
# Name: Valor_Venda, Length: 480, dtype: float64

# %% [markdown]
# ### Pergunta de Negócio 2:
#
# #### Qual o Total de Vendas Por Data do Pedido?

# %%
#agrupando e realizando a soma
df_p2 = df.groupby('Data_Pedido')['Valor_Venda'].sum()

# %%
#visualizando os dados
df_p2.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
# Name: Valor_Venda, dtype: float64

# %%
#plotando grafico
plt.figure(figsize = (20, 6))
ax = df_p2.plot(x = 'Data_Pedido', y = 'Valor_Venda', color = 'darkblue')
ax.set_ylabel('Valor venda')
ax.set_xlabel('Data do Pedido')
plt.title('Total de Vendas por Data do Pedido')
plt.show()

# %% [markdown]
# ### Pergunta de Negócio 3:
#
# #### Qual o Total de Vendas por Estado?

# %%
#agrupando por estado e realizando a soma
df_p3 = df.groupby('Estado')['Valor_Venda'].sum().reset_index()

# %%
#plotando grafico
plt.figure(figsize = (16, 6))
sns.barplot(data = df_p3, y = 'Valor_Venda', x = 'Estado').set(title = 'Total de Vendas por Estado')
plt.xticks(rotation = 85)
plt.show()

# %% [markdown]
# ### Pergunta de Negócio 4:
#
# #### Quais São as 10 Cidades com Maior Total de Vendas?

# %%
df_p4 = df.groupby('Cidade')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending = False)

# %%
df_p4 = df_p4.head(10)

# %%
#plotando grafico
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = df_p4, y = 'Valor_Venda', x = 'Cidade').set(title = 'As 10 Cidade com Maior Total de Vendas')
plt.show()

# %% [markdown]
# ### Pergunta de Negócio 5:
#
# #### Qual Segmento Teve o Maior Total de Vendas?

# %%
df_p5 = df.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending = False)

# %%
df_p5.head()
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %%
#convertendo os valores dos dados em valor absoluto
def autopct_format(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

# %%
#plot
plt.figure(figsize =(16, 6))

#grafico de pizza
plt.pie(df_p5['Valor_Venda'], 
        labels = df_p5['Segmento'],
        autopct = autopct_format(df_p5['Valor_Venda']),
        startangle = 90)

#limpa o circulo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

#labels e anotaçoes
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_p5['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas por Segmento')
plt.show()

# %% [markdown]
# ### Pergunta de Negócio 6:
#
# #### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
#convertendo a coluna de data para o time datetime
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], dayfirst = True)

# %%
df.head(3)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
#
#         Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0    Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1    Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2  Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
#
#    Valor_Venda
# 0       261.96
# 1       731.94
# 2        14.62

# %%
df.dtypes
# Out:
# ID_Pedido               object
# Data_Pedido     datetime64[ns]
# ID_Cliente              object
# Segmento                object
# Pais                    object
# Cidade                  object
# Estado                  object
# ID_Produto              object
# Categoria               object
# SubCategoria            object
# Valor_Venda            float64
# dtype: object

# %%
#extraindo o ano criando nova variavel
df['Ano'] = df['Data_Pedido'].dt.year

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# ...

# %%
#total de vendas por segmento e por ano
df_p6 = df.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum()

# %%
df_p6
# Out:
# Ano   Segmento
# 2015  Consumer       256719.9166
#       Corporate      125819.5957
#       Home Office     88229.0878
# 2016  Consumer       265295.2593
#       Corporate      114643.1229
#       Home Office     74134.1332
# 2017  Consumer       288459.5572
#       Corporate      203266.7398
#       Home Office    103639.6270
# 2018  Consumer       323359.6019
#       Corporate      235502.7284
#       Home Office    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ### Pergunta de Negócio 7:
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# #### Quantas Vendas Receberiam 15% de Desconto?

# %%
#criando uma nova coluna de acordo com a regra
df['Desconto'] = np.where(df['Valor_Venda'] > 1000, 0.15, 0.10)   #se > 1000 = 0.15, senao = 0.10

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto
# 0     261.9600  2017       0.1
# ...

# %%
#total por cada valor da variavel
df['Desconto'].value_counts()
# Out:
# 0.10    9243
# 0.15     457
# Name: Desconto, dtype: int64

# %%
print('No total 457 vendas receberiam o desconto de 15%')
# Out:
# No total 457 vendas receberiam o desconto de 15%

# %% [markdown]
# ### Pergunta de Negócio 8 (Desafio Nível Master):
#
# #### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
#criando uma nova coluna calculando o valor de venda menos o desconto
df['Valor_Venda_Desconto'] = df['Valor_Venda'] - (df['Valor_Venda'] * df['Desconto'])

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto
# ...

# %%
#filtrando as vendas antes do desconto
df_p8_antes_desconto = df.loc[df['Desconto'] == 0.15, 'Valor_Venda']

# %%
#filtrando apos desconto
df_p8_depois_desconto = df.loc[df['Desconto'] == 0.15, 'Valor_Venda_Desconto']

# %%
#calculando media antes do desconto
media_vendas_antes_desconto = df_p8_antes_desconto.mean()

# %%
media_vendas_depois_desconto = df_p8_depois_desconto.mean()

# %%
print(f'Média das vendas antes do desconto de 15%: {media_vendas_antes_desconto:.2f}')
print(f'Média das vendas depois do desconto de 15%: {media_vendas_depois_desconto:.2f}')
# Out:
# Média das vendas antes do desconto de 15%: 2116.81
# Média das vendas depois do desconto de 15%: 1799.29

# %% [markdown]
# ### Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# #### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?

# %%
#extraindo o mes e gravando em uma nova variavel
df['Mes'] = df['Data_Pedido'].dt.month

# %%
#agrupando por ano, mes e segmento e calculando estatisticas de agregação
df_p9 = df.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])

# %%
df_p9
# Out:
#                              sum        mean  median
# Ano  Mes Segmento
# 2015 1   Consumer      6896.6290  146.736787  36.440
#          Corporate     1701.5280  130.886769  51.940
#          Home Office   5607.5500  329.855882  62.820
#      2   Consumer      3167.8540  117.327926  22.776
#          Corporate      623.1180   69.235333  62.310
# ...                          ...         ...     ...
# 2018 11  Corporate    44357.9862  341.215278  79.530
#          Home Office  24009.3840  247.519423  56.560
#      12  Consumer     48107.4558  183.616244  52.533
#          Corporate    20524.4320  153.167403  46.460
#          Home Office  13022.3910  224.523983  49.260
#
# [144 rows x 3 columns]

# %%
#extraindo os niveis
anos = df_p9.index.get_level_values(0)
meses = df_p9.index.get_level_values(1)
segmentos = df_p9.index.get_level_values(2)

# %%
#plot
plt.figure(figsize = (12, 6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = df_p9,
                   y = 'mean',
                   x = meses,
                   hue = segmentos,
                   col = anos,
                   col_wrap = 2)
plt.show()

# %% [markdown]
# ### Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# #### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?

# %%
df.head(3)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
#
#         Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0    Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1    Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2  Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# 0       261.96  2017       0.1               235.764   11
# 1       731.94  2017       0.1               658.746   11
# 2        14.62  2017       0.1                13.158    6

# %%
#agrupando por categoria e subcategoria e calculando a soma somente para variaveis numericas
df_p10 = df.groupby(['Categoria', 'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda', ascending = False).head(12)

# %%
#convertendo a coluna valor_venda em numero inteiro e classificando por categoria
df_p10 = df_p10[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %%
#dataframe com categorias e subcategorias
df_p10
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
#criando outro dataframe somente com os totais por categoria
df_p10_cat = df_p10.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
#dataframe com categorias
df_p10_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
#listas de cores para categorias
cores_categorias = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Listas de cores para subcategorias
cores_subcategorias = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Plot

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(df_p10_cat['Valor_Venda'], 
            radius = 1,
            labels = df_p10_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = cores_categorias)

# Gráfico das subcategorias
p2 = ax.pie(df_p10['Valor_Venda'],
            radius = 0.9,
            labels = df_p10['SubCategoria'],
            autopct = autopct_format(df_p10['Valor_Venda']),
            colors = cores_subcategorias, 
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'), 
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_p10['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()
